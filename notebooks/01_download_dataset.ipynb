# %%
# [CELDA 1] - Instalación de dependencias si es necesario
# !pip install roboflow

# ---

# [CELDA 2] - Descarga del dataset
import os
from roboflow import Roboflow

# NOTA: Para obtener tu API Key gratuita de Roboflow:
# 1. Creá una cuenta en https://roboflow.com
# 2. Copiá tu Private API Key desde Account Settings -> API
ROBOFLOW_API_KEY = "jUmxZSRcOZsg6XTdBnY3"  # Reemplazá por tu clave de Roboflow

# Especificamos la ruta de salida para guardar el dataset en la raíz del proyecto
dataset_dir = os.path.abspath("../dataset")

try:
    rf = Roboflow(api_key=ROBOFLOW_API_KEY)
    
    # Dataset público de Roboflow Universe para Detección de Humos
    project = rf.workspace("wildfire-dataset").project("smoke-detection-q5vvg")
    dataset = project.download("yolov8", location=dataset_dir)
    
    print(f"✅ Dataset descargado exitosamente en: {dataset_dir}")
except Exception as e:
    print("❌ Error al descargar con Roboflow. Verifica tu API Key.")
    print("Detalle del error:", e)

# ---

# [CELDA 3] - Verificación de la estructura descargada
print("\nArchivos creados en el directorio del dataset:")
if os.path.exists(dataset_dir):
    for root, dirs, files in os.walk(dataset_dir):
        level = root.replace(dataset_dir, '').count(os.sep)
        indent = ' ' * 4 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 4 * (level + 1)
        for f in files[:3]:  # Mostramos los primeros 3 archivos por carpeta
            print(f"{subindent}{f}")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 MB 4.4 MB/s eta 0:00:0000:0100:01m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 7.6 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.2 MB/s eta 0:00:00
# ...
